# %%
import matplotlib.pyplot as plt
import numpy as np
from utils import *

# %%
result = {}
test_cases = [0,1,2,3,4,5]
colors = ["blue", "red", "green", "yellow", "purple", "orange"]

for tc in test_cases:
    model_folder = f"../training/saved/2024-03-30/{tc}_1_8_octaves"
    archive = np.load(model_folder + "/predictions.npz")
    y_pred = archive["y_pred"]
    y_gt = archive["y_gt"]

    x_values = []
    y_values = []

    gt_freq = [0] * 100
    pred_freq = [0] * 100

    pred, gt = compute_pitch_list_from_archive(y_pred, y_gt)

    for i in range(len(gt)):
        gt_i = gt[i]
        pred_i = pred[i]
        #if there is a pitch greater than 0
        if gt_i > 0:
            gt_freq[gt_i] += 1
            if gt_i == pred_i:
                pred_freq[pred_i] += 1

    for i in range(40, 84):
        if gt_freq[i] > 0:
            r = pred_freq[i] / gt_freq[i]
            x_values.append(i)
            y_values.append(r)

    print(f"Test case 0{tc} - {sum(y_values)/len(y_values)}")
    result[f"test_0{tc}"] = {"x" : x_values, "y" : y_values}
# Out:
# Test case 00 - 0.6193497489547484
# Test case 01 - 0.7887888158754385
# Test case 02 - 0.743052716187997
# Test case 03 - 0.7659726221666757
# Test case 04 - 0.7642615290621568
# Test case 05 - 0.7777048820953679

# %%
plt.figure(figsize=(20, 10), facecolor="white")


for i, tc in enumerate(result.keys()):
    x_values = result[tc]["x"]
    y_values = result[tc]["y"]
    plt.plot(x_values, y_values, label=tc, color=colors[i])

plt.xlabel("Note midi")
plt.ylabel("% corecte")
plt.grid(True)
plt.title("Procentul notelor midi corect identificate")
plt.legend()
plt.show()

# %%
x_values_all = []
y_values_all = []
for i in range(40, 84):
    y_val = 0
    k = 0
    for tc in result.keys():
        if i in result[tc]["x"]:
            y_val += result[tc]["y"][result[tc]["x"].index(i)]
            k += 1
    if k > 0:
        x_values_all.append(i)
        y_values_all.append(y_val/k)

plt.figure(figsize=(20,10))
plt.xlabel("Note midi")
plt.ylabel("% corecte")
plt.grid(True)
plt.title("Procentul notelor midi corect identificate (media)")
plt.plot(x_values_all, y_values_all, color='black', label='medie teste')
plt.legend()
plt.show()
